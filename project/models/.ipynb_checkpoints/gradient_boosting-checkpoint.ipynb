# %%
import pandas as pd
import numpy as np

import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error
from xgboost import XGBRFRegressor
from tqdm.auto import tqdm

from itertools import product

from functions.graph_with_prediction import graph_with_prediction

# %%
train_data = pd.read_csv('../../data/preprocessed_data/train_year_oil_rate_50_days_ago_without_gaps.csv')
train_data.sort_values(by='MEASURED_IN_DATE', inplace=True)
train_data['MEASURED_IN_DATE'] = pd.to_datetime(train_data['MEASURED_IN_DATE'])
train_data.set_index('MEASURED_IN_DATE', inplace=True)


train_data_one_well = train_data[train_data['WELL_NAME'] == 1]

X = train_data_one_well.iloc[:, : -1]
y = train_data_one_well['TARGET_OIL_RATE']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, shuffle=False)

X_train.head()
# Out:
#                   WELL_NAME  OIL_RATE_50_days_ago  OIL_RATE_49_days_ago
# MEASURED_IN_DATE
# 2020-10-20                1                 98.80                 97.60  \
# 2020-10-21                1                 97.60                 99.63
# 2020-10-22                1                 99.63                 96.40
# 2020-10-23                1                 96.40                 91.20
# 2020-10-24                1                 91.20                 90.82
#
#                   OIL_RATE_48_days_ago  OIL_RATE_47_days_ago
# MEASURED_IN_DATE
# 2020-10-20                       99.63                 96.40  \
# 2020-10-21                       96.40                 91.20
# 2020-10-22                       91.20                 90.82
# 2020-10-23                       90.82                 92.82
# 2020-10-24                       92.82                 96.76
#
#                   OIL_RATE_46_days_ago  OIL_RATE_45_days_ago
# MEASURED_IN_DATE
# 2020-10-20                       91.20                 90.82  \
# 2020-10-21                       90.82                 92.82
# 2020-10-22                       92.82                 96.76
# 2020-10-23                       96.76                 96.76
# 2020-10-24                       96.76                 95.94
#
#                   OIL_RATE_44_days_ago  OIL_RATE_43_days_ago
# MEASURED_IN_DATE
# 2020-10-20                       92.82                 96.76  \
# 2020-10-21                       96.76                 96.76
# 2020-10-22                       96.76                 95.94
# 2020-10-23                       95.94                 94.71
# 2020-10-24                       94.71                 92.40
#
#                   OIL_RATE_42_days_ago  ...  OIL_RATE_10_days_ago
# MEASURED_IN_DATE                        ...
# 2020-10-20                       96.76  ...                 70.56  \
# 2020-10-21                       95.94  ...                 62.08
# 2020-10-22                       94.71  ...                 62.08
# 2020-10-23                       92.40  ...                 60.14
# 2020-10-24                       92.40  ...                 59.83
#
#                   OIL_RATE_9_days_ago  OIL_RATE_8_days_ago
# MEASURED_IN_DATE
# 2020-10-20                      62.08                62.08  \
# 2020-10-21                      62.08                60.14
# 2020-10-22                      60.14                59.83
# 2020-10-23                      59.83                59.83
# 2020-10-24                      59.83                59.83
#
#                   OIL_RATE_7_days_ago  OIL_RATE_6_days_ago
# MEASURED_IN_DATE
# 2020-10-20                      60.14                59.83  \
# 2020-10-21                      59.83                59.83
# 2020-10-22                      59.83                59.83
# 2020-10-23                      59.83                59.52
# 2020-10-24                      59.52                59.52
#
#                   OIL_RATE_5_days_ago  OIL_RATE_4_days_ago
# MEASURED_IN_DATE
# 2020-10-20                      59.83                59.83  \
# 2020-10-21                      59.83                59.52
# 2020-10-22                      59.52                59.52
# 2020-10-23                      59.52                59.21
# 2020-10-24                      59.21                59.21
#
#                   OIL_RATE_3_days_ago  OIL_RATE_2_days_ago
# MEASURED_IN_DATE
# 2020-10-20                      59.52                59.52  \
# 2020-10-21                      59.52                59.21
# 2020-10-22                      59.21                59.21
# 2020-10-23                      59.21                59.21
# 2020-10-24                      59.21                59.21
#
#                   OIL_RATE_1_days_ago
# MEASURED_IN_DATE
# 2020-10-20                      59.21
# 2020-10-21                      59.21
# 2020-10-22                      59.21
# 2020-10-23                      59.21
# 2020-10-24                      59.21
#
# [5 rows x 51 columns]

# %%
params = {'n_estimators': range(301, 100),
          'max_depth': range(1, 20, 3),
          'max_leaves': range(1, 20, 3),
          'learning_rate': [3 * 10 ** -4, 0.1, 0.3, 0.6, 0.7]}

param_values = list(params.values())
combinations = list(product(*param_values))


best_score = np.inf
best_params = None 

for comb in tqdm(combinations, desc='Processing'):
    
    model = XGBRFRegressor(n_estimators=comb[0], max_depth=comb[1], max_leaves=comb[2], learning_rate=comb[3], n_jobs=-1)
    model.fit(X_train, y_train)
    
    
    data = X_test.iloc[[0]]
    
    total_point = X_test.shape[0]
    count_days_ago = data.shape[1] - 1

    answer = []

    for i in range(total_point):

        value_point = float(model.predict(data))

        answer.append(value_point)

        data.iloc[0 , - count_days_ago : - 1] = data.iloc[0 , - count_days_ago + 1 : ]
        data.iloc[0 , - 1] = value_point

    answer = pd.Series(answer, index=y_test.index)
    
    
    score = mean_absolute_error(y_test, answer)
    
    if score < best_score:
        best_score = score
        best_params = comb
    pbar.update()
# Out:
# [(range(301, 100),), (range(1, 20, 3),), (range(1, 20, 3),), ([0.00030000000000000003, 0.1, 0.3, 0.6, 0.7],)]
# Processing: 0it [00:00, ?it/s]

# %%
best_params
model = XGBRFRegressor(n_estimators=best_params[0], 
                       max_depth=best_params[1], 
                       max_leaves=best_params[2], 
                       learning_rate=best_params[3])
model.fit(X_train, y_train)
importances = model.feature_importances_


fig, axes = plt.subplots(figsize=(8,5))
sns.barplot(x=X_train.columns, y=importances);
axes.set_ylabel('Важность признака')
axes.set_xlabel('Признаки')
x_ticklabels = axes.get_xticklabels()
for label in x_ticklabels:
    label.set_rotation(45)
    label.set_fontsize(8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 best_params
# ----> 2 model = XGBRFRegressor(n_estimators=best_params[0],
#       3                        max_depth=best_params[1],
#       4                        max_leaves=best_params[2],
#       5                        learning_rate=best_params[3])
#       6 model.fit(X_train, y_train)
#       7 importances = model.feature_importances_
#
# TypeError: 'NoneType' object is not subscriptable

# %%
data = X_test.iloc[[0]]

total_point = X_test.shape[0]
count_days_ago = data.shape[1] - 1

answer = []

for i in range(total_point):
    
    value_point = float(model.predict(data))
    
    
    answer.append(value_point)
        
    data.iloc[0 , - count_days_ago : - 1] = data.iloc[0 , - count_days_ago + 1 : ]
    data.iloc[0 , - 1] = value_point

answer = pd.Series(answer, index=y_test.index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 10
#       6 answer = []
#       8 for i in range(total_point):
# ---> 10     value_point = float(model.predict(data))
#      13     answer.append(value_point)
#      15     data.iloc[0 , - count_days_ago : - 1] = data.iloc[0 , - count_days_ago + 1 : ]
#
# NameError: name 'model' is not defined

# %%
graph_with_prediction(y_train=y_train, y_test=y_test, answer_model=answer, model_name='Xgboost')
# Out:
# <div>                            <div id="9ec3e9b4-fdaf-425a-a414-5280227de5e3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9ec3e9b4-fdaf-425a-a414-5280227de5e3")) {                    Plotly.newPlot(                        "9ec3e9b4-fdaf-425a-a414-5280227de5e3",                        [{"mode":"lines","name":"\u041c\u043e\u0434\u0435\u043b\u044c - Xgboost","x":["2020-09-05T00:00:00","2020-09-06T00:00:00","2020-09-07T00:00:00","2020-09-08T00:00:00","2020-09-09T00:00:00","2020-09-10T00:00:00","2020-09-11T00:00:00","2020-09-12T00:00:00","2020-09-13T00:00:00","2020-09-14T00:00:00","2020-09-15T00:00:00","2020-09-16T00:00:00","2020-09-17T00:00:00","2020-09-18T00:00:00","2020-09-19T00:00:00","2020-09-20T00:00:00","2020-09-21T00:00:00","2020-09-22T00:00:00","2020-09-23T00:00:00","2020-09-24T00:00:00","2020-09-25T00:00:00","2020-09-26T00:00:00","2020-09-27T00:00:00","2020-09-28T00:00:00","2020-09-29T00:00:00","2020-09-30T00:00:00","2020-10-01T00:00:00","2020-10-02T00:00:00","2020-10-03T00:00:00","2020-10-04T00:00:00","2020-10-05T00:00:00","2020-10-06T00:00:00","2020-10-07T00:00:00","2020-10-08T00:00:00","2020-10-09T00:00:00","2020-10-10T00:00:00","2020-10-11T00:00:00","2020-10-12T00:00:00","2020-10-13T00:00:00","2020-10-14T00:00:00","2020-10-15T00:00:00","2020-10-16T00:00:00","2020-10-17T00:00:00","2020-10-18T00:00:00","2020-10-19T00:00:00","2020-10-20T00:00:00","2020-10-21T00:00:00","2020-10-22T00:00:00","2020-10-23T00:00:00","2020-10-24T00:00:00","2020-10-25T00:00:00","2020-10-26T00:00:00","2020-10-27T00:00:00","2020-10-28T00:00:00","2020-10-29T00:00:00","2020-10-30T00:00:00","2020-10-31T00:00:00","2020-11-01T00:00:00","2020-11-02T00:00:00","2020-11-03T00:00:00","2020-11-04T00:00:00","2020-11-05T00:00:00","2020-11-06T00:00:00","2020-11-07T00:00:00","2020-11-08T00:00:00","2020-11-09T00:00:00","2020-11-10T00:00:00","2020-11-11T00:00:00","2020-11-12T00:00:00","2020-11-13T00:00:00","2020-11-14T00:00:00","2020-11-15T00:00:00","2020-11-16T00:00:00","2020-11-17T00:00:00","2020-11-18T00:00:00","2020-11-19T00:00:00","2020-11-20T00:00:00","2020-11-21T00:00:00","2020-11-22T00:00:00","2020-11-23T00:00:00","2020-11-24T00:00:00","2020-11-25T00:00:00","2020-11-26T00:00:00","2020-11-27T00:00:00","2020-11-28T00:00:00","2020-11-29T00:00:00","2020-11-30T00:00:00","2020-12-01T00:00:00","2020-12-02T00:00:00","2020-12-03T00:00:00","2020-12-04T00:00:00","2020-12-05T00:00:00","2020-12-06T00:00:00","2020-12-07T00:00:00","2020-12-08T00:00:00","2020-12-09T00:00:00","2020-12-10T00:00:00","2020-12-11T00:00:00","2020-12-12T00:00:00","2020-12-13T00:00:00","2020-12-14T00:00:00","2020-12-15T00:00:00","2020-12-16T00:00:00","2020-12-17T00:00:00","2020-12-18T00:00:00","2020-12-19T00:00:00","2020-12-20T00:00:00","2020-12-21T00:00:00","2020-12-22T00:00:00","2020-12-23T00:00:00","2020-12-24T00:00:00","2020-12-25T00:00:00","2020-12-26T00:00:00","2020-12-27T00:00:00","2020-12-28T00:00:00","2020-12-29T00:00:00","2020-12-30T00:00:00","2020-12-31T00:00:00","2021-01-01T00:00:00","2021-01-02T00:00:00","2021-01-03T00:00:00","2021-01-04T00:00:00","2021-01-05T00:00:00","2021-01-06T00:00:00","2021-01-07T00:00:00","2021-01-08T00:00:00","2021-01-09T00:00:00","2021-01-10T00:00:00","2021-01-11T00:00:00","2021-01-12T00:00:00","2021-01-13T00:00:00","2021-01-14T00:00:00","2021-01-15T00:00:00","2021-01-16T00:00:00","2021-01-17T00:00:00","2021-01-18T00:00:00","2021-01-19T00:00:00","2021-01-20T00:00:00","2021-01-21T00:00:00","2021-01-22T00:00:00","2021-01-23T00:00:00","2021-01-24T00:00:00","2021-01-25T00:00:00","2021-01-26T00:00:00","2021-01-27T00:00:00","2021-01-28T00:00:00","2021-01-29T00:00:00","2021-01-30T00:00:00","2021-01-31T00:00:00","2021-02-01T00:00:00","2021-02-02T00:00:00","2021-02-03T00:00:00","2021-02-04T00:00:00","2021-02-05T00:00:00","202 ...
