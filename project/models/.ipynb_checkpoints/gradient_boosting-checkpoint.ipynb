# %%
from IPython.display import clear_output
import os


import pandas as pd
import numpy as np

import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error
from xgboost import XGBRFRegressor
from tqdm.auto import tqdm

from itertools import product

from functions.graph_with_prediction import graph_with_prediction
from functions.train_test_wells import train_test_wells
import matplotlib.pyplot as plt

# %%
train_data = pd.read_csv('../../data/data_for_model/dataframes/20_days_ago_not_stat.csv')
train_data.sort_values(by='MEASURED_IN_DATE', inplace=True)
train_data['MEASURED_IN_DATE'] = pd.to_datetime(train_data['MEASURED_IN_DATE'])
train_data.set_index('MEASURED_IN_DATE', inplace=True)


train_data_one_well = train_data[train_data['WELL_NAME'] == 1]

X = train_data_one_well.iloc[:, : -1]
y = train_data_one_well['TARGET_OIL_RATE']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, shuffle=False)

X_train.head()
# Out:
#                   WELL_NAME  OIL_RATE_20_days_ago  OIL_RATE_19_days_ago
# MEASURED_IN_DATE
# 2020-09-20                1                 98.80                 97.60  \
# 2020-09-21                1                 97.60                 99.63
# 2020-09-22                1                 99.63                 96.40
# 2020-09-23                1                 96.40                 91.20
# 2020-09-24                1                 91.20                 90.82
#
#                   OIL_RATE_18_days_ago  OIL_RATE_17_days_ago
# MEASURED_IN_DATE
# 2020-09-20                       99.63                 96.40  \
# 2020-09-21                       96.40                 91.20
# 2020-09-22                       91.20                 90.82
# 2020-09-23                       90.82                 92.82
# 2020-09-24                       92.82                 96.76
#
#                   OIL_RATE_16_days_ago  OIL_RATE_15_days_ago
# MEASURED_IN_DATE
# 2020-09-20                       91.20                 90.82  \
# 2020-09-21                       90.82                 92.82
# 2020-09-22                       92.82                 96.76
# 2020-09-23                       96.76                 96.76
# 2020-09-24                       96.76                 95.94
#
#                   OIL_RATE_14_days_ago  OIL_RATE_13_days_ago
# MEASURED_IN_DATE
# 2020-09-20                       92.82                 96.76  \
# 2020-09-21                       96.76                 96.76
# 2020-09-22                       96.76                 95.94
# 2020-09-23                       95.94                 94.71
# 2020-09-24                       94.71                 92.40
#
#                   OIL_RATE_12_days_ago  ...  OIL_RATE_10_days_ago
# MEASURED_IN_DATE                        ...
# 2020-09-20                       96.76  ...                 94.71  \
# 2020-09-21                       95.94  ...                 92.40
# 2020-09-22                       94.71  ...                 92.40
# 2020-09-23                       92.40  ...                 92.40
# 2020-09-24                       92.40  ...                 92.40
#
#                   OIL_RATE_9_days_ago  OIL_RATE_8_days_ago
# MEASURED_IN_DATE
# 2020-09-20                       92.4                 92.4  \
# 2020-09-21                       92.4                 92.4
# 2020-09-22                       92.4                 92.4
# 2020-09-23                       92.4                 92.4
# 2020-09-24                       92.4                 92.4
#
#                   OIL_RATE_7_days_ago  OIL_RATE_6_days_ago
# MEASURED_IN_DATE
# 2020-09-20                       92.4                 92.4  \
# 2020-09-21                       92.4                 92.4
# 2020-09-22                       92.4                 92.4
# 2020-09-23                       92.4                 92.4
# 2020-09-24                       92.4                 92.4
#
#                   OIL_RATE_5_days_ago  OIL_RATE_4_days_ago
# MEASURED_IN_DATE
# 2020-09-20                       92.4                 92.4  \
# 2020-09-21                       92.4                 92.4
# 2020-09-22                       92.4                 92.4
# 2020-09-23                       92.4                 89.6
# 2020-09-24                       89.6                 87.2
#
#                   OIL_RATE_3_days_ago  OIL_RATE_2_days_ago
# MEASURED_IN_DATE
# 2020-09-20                      92.40                92.40  \
# 2020-09-21                      92.40                89.60
# 2020-09-22                      89.60                87.20
# 2020-09-23                      87.20                84.63
# 2020-09-24                      84.63                83.85
#
#                   OIL_RATE_1_days_ago
# MEASURED_IN_DATE
# 2020-09-20                      89.60
# 2020-09-21                      87.20
# 2020-09-22                      84.63
# 2020-09-23                      83.85
# 2020-09-24                      81.32
#
# [5 rows x 21 columns]

# %%
params = {'n_estimators': range(1, 301, 100),
          'max_depth': range(1, 20, 3),
          'max_leaves': range(1, 20, 3),
          'learning_rate': [3 * 10 ** -4, 0.1, 0.3, 0.6, 0.7]}

param_values = list(params.values())
combinations = list(product(*param_values))


best_score = np.inf
best_params = None 

pbar = tqdm(total=len(combinations), desc='Processing')

for comb in combinations:
    
    model = XGBRFRegressor(n_estimators=comb[0], max_depth=comb[1], max_leaves=comb[2], learning_rate=comb[3], n_jobs=-1)
    model.fit(X_train, y_train)
    
    
    data = X_test.iloc[[0]]
    
    total_point = X_test.shape[0]
    count_days_ago = data.shape[1] - 1

    answer = []

    for i in range(total_point):

        value_point = float(model.predict(data))

        answer.append(value_point)

        data.iloc[0 , - count_days_ago : - 1] = data.iloc[0 , - count_days_ago + 1 : ]
        data.iloc[0 , - 1] = value_point

    answer = pd.Series(answer, index=y_test.index)
    
    
    score = mean_absolute_error(y_test, answer)
    
    if score < best_score:
        best_score = score
        best_params = comb
    pbar.update()
# Out:
# Processing: 100%|████████████████████████████████████████████████████████████████████| 735/735 [04:13<00:00,  1.61it/s]

# %%
path_to_dir_with_data = '../../data/data_for_model/dataframes/'
name_files = os.listdir(path_to_dir_with_data)[1:2]
name_files
# Out:
# ['20_days_ago_not_stat.csv']

# %%
clear_output(wait=True)


target = 'OIL_RATE'
test_sizes = [30, 45, 60, 120]


params = {'n_estimators': range(1, 301, 100),
          'max_depth': range(1, 10, 3),
          'max_leaves': range(1, 10, 3),
          'learning_rate': [0.1, 0.3, 0.6, 0.7]}


path_to_dir_with_data = '../../data/data_for_model/dataframes/'
name_files = os.listdir(path_to_dir_with_data)[1:]



parameters = list(params.values())
parameters_list = list(product(*parameters))


for data_name in tqdm(name_files, desc='Csv', colour='red', leave=False, position=0):
    
    count_feature = int(data_name.split('_')[0])
    
    path_to_data = f'{path_to_dir_with_data}{data_name}'
    df = pd.read_csv(path_to_data)
    
    df['MEASURED_IN_DATE'] = pd.to_datetime(df['MEASURED_IN_DATE'])
    df.set_index('MEASURED_IN_DATE', inplace=True)
    
    for test_size in test_sizes:
        X_train, X_test, y_train, y_test = train_test_wells(df, target=target , test_size=test_size)
        X_train = X_train.astype('float')
        X_test = X_test.astype('float') 
        y_train = y_train.astype('float') 
        y_test = y_test.astype('float')
        
        for param in parameters_list:
            
            
            try:
                
                model = XGBRFRegressor(n_estimators=param[0], 
                                       max_depth=param[1], 
                                       max_leaves=param[2], 
                                       learning_rate=param[3], 
                                       n_jobs=-1)
                model.fit(X_train, y_train[f'TARGET_{target}'])
                
                for well in list(df['WELL_NAME'].unique()):

                    X_test_well = X_test[X_test['WELL_NAME'] == well]
                    y_test_well = y_test[y_test['WELL_NAME'] == well][f'TARGET_{target}']

                    data = X_test_well.iloc[[0]]

                    total_points = X_test_well.shape[0]

                    answer = []

                    for point in range(total_points):
                        
                        value_point = float(model.predict(data))
                        
                        
                        answer.append(value_point)

                        if len(answer) == total_points:
                            break

                        data.index = [X_test_well.index[point + 1]]
                        data.iloc[:, : - count_feature] = [X_test_well.iloc[point + 1, : - count_feature]]

                        data.iloc[:, - count_feature : -1] = data.iloc[:, - count_feature + 1 :];
                        data.iloc[:, - 1] = value_point

                    answer = pd.Series(answer, index=y_test_well.index).astype('float')

                    MSE = mean_squared_error(y_test_well, answer) 
                    MAE = mean_absolute_error(y_test_well, answer)
                    
                    result_new.loc[result_new.shape[0]] = [data_name, 
                                                   well, 
                                                   param[0], 
                                                   param[1],
                                                   param[2],
                                                   param[3],
                                                   count_feature,
                                                   test_size,  
                                                   MSE, 
                                                   MAE]

                    result_new.drop_duplicates(inplace=True)
                    
            except ValueError:
                    result_new.loc[result_new.shape[0]] = [data_name, 
                                                           np.nan, 
                                                           param[0], 
                                                           param[1],
                                                           param[2],
                                                           param[3],
                                                           count_feature,
                                                           test_size,
                                                           np.nan, 
                                                           np.nan]
                    result_new.drop_duplicates(inplace=True)
                    continue

# %% [markdown]
# result_new = pd.DataFrame(columns=['DATAFRAME_NAME', 'WELL_NAME', 'N_ESTIMATORS',
#                                    'MAX_DEPTH', 'MAX_LEAVES', 'LEARNING_RATE', 'DAY_AGO',
#                                    'PREDICT_DAYS', 'MSE', 'MAE'], )
#
# result_new

# %%
result_new.to_csv('../../data/data_for_model/gradient_boosting/result_new.csv')

# %%
result_new.groupby(['DATAFRAME_NAME', 
                    'N_ESTIMATORS', 'MAX_DEPTH', 
                    'MAX_LEAVES', 'LEARNING_RATE', 
                    'DAY_AGO', 'PREDICT_DAYS']).mean().dropna().sort_values(by=['MSE', 'MAE'])
# Out:
#                                                                                                                           WELL_NAME
# DATAFRAME_NAME                                     N_ESTIMATORS MAX_DEPTH MAX_LEAVES LEARNING_RATE DAY_AGO PREDICT_DAYS
# 20_days_ago_not_stat.csv                           1            1         1          0.7           20      30            127.443662  \
#                                                                           4          0.7           20      30            127.443662
#                                                                           7          0.7           20      30            127.443662
# 50_days_ago_not_stat_P_ZAB_not_stat_inj_not_sta... 201          1         1          0.7           50      30            127.443662
#                                                                           4          0.7           50      30            127.443662
# ...                                                                                                                             ...
#                                                    101          7         7          0.1           50      60            127.443662
#                                                    1            7         1          0.1           50      60            127.443662
#                                                                           4          0.1           50      60            127.443662
#                                                                           7          0.1           50      60            127.443662
# 20_days_ago_not_stat.csv                           1            4         1          0.6           20      30             84.721649
#
#                                                                                                                                   MSE
# DATAFRAME_NAME                                     N_ESTIMATORS MAX_DEPTH MAX_LEAVES LEARNING_RATE DAY_AGO PREDICT_DAYS
# 20_days_ago_not_stat.csv                           1            1         1          0.7           20      30             7207.384066  \
#                                                                           4          0.7           20      30             7207.384066
#                                                                           7          0.7           20      30             7207.384066
# 50_days_ago_not_stat_P_ZAB_not_stat_inj_not_sta... 201          1         1          0.7           50      30             7351.353161
#                                                                           4          0.7           50      30             7351.353161
# ...                                                                                                                               ...
#                                                    101          7         7          0.1           50      60            38629.930330
#                                                    1            7         1          0.1           50      60            38657.021395
#                                                                           4          0.1           50      60            38657.021395
#                                                                           7          0.1           50      60            38657.021395
# 20_days_ago_not_stat.csv                           1            4         1          0.6           20      30            40121.228442
#
#                                                                                                                                 MAE
# DATAFRAME_NAME                                     N_ESTIMATORS MAX_DEPTH MAX_LEAVES LEARNING_RATE DAY_AGO PREDICT_DAYS
# 20_days_ago_not_stat.csv                           1            1         1          0.7           20      30             59.657922
#                                                                           4          0.7           20      30             59.657922
#                                                                           7          0.7           20      30             59.657922
# 50_days_ago_not_stat_P_ZAB_not_stat_inj_not_sta... 201          1         1          0.7           50      30             59.864851
#                                                                           4          0.7           50      30             59.864851
# ...                                                                                                                             ...
#                                                    101          7         7          0.1           50      60            137.414400
#                                                    1            7         1          0.1           50      60            137.465987
#                                                                           4          0.1           50      60            137.465987
#                                                                           7          0.1           50      60            137.465987
# 20_days_ago_not_stat.csv                           1            4         1          0.6           20      30            131.586327
#
# [333 rows x 3 columns]

# %%
model = XGBRFRegressor(n_estimators=param[0], 
                                       max_depth=param[1], 
                                       max_leaves=param[2], 
                                       learning_rate=param[3], 
                                       n_jobs=-1)
X_train = X_train.astype('float')
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 23260 entries, 2020-09-20 to 2021-05-27
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   WELL_NAME             23260 non-null  float64
#  1   OIL_RATE_20_days_ago  23260 non-null  float64
#  2   OIL_RATE_19_days_ago  23260 non-null  float64
#  3   OIL_RATE_18_days_ago  23260 non-null  float64
#  4   OIL_RATE_17_days_ago  23260 non-null  float64
#  5   OIL_RATE_16_days_ago  23260 non-null  float64
#  6   OIL_RATE_15_days_ago  23260 non-null  float64
#  7   OIL_RATE_14_days_ago  23260 non-null  float64
#  8   OIL_RATE_13_days_ago  23260 non-null  float64
#  9   OIL_RATE_12_days_ago  23260 non-null  float64
#  10  OIL_RATE_11_days_ago  23260 non-null  float64
#  11  OIL_RATE_10_days_ago  23260 non-null  float64
#  12  OIL_RATE_9_days_ago   23260 non-null  float64
#  13  OIL_RATE_8_days_ago   23260 non-null  float64
#  14  OIL_RATE_7_days_ago   23260 non-null  float64
#  15  OIL_RATE_6_days_ago   23260 non-null  float64
#  16  OIL_RATE_5_days_ago   23260 non-null  float64
#  17  OIL_RATE_4_days_ago   23260 non-null  float64
#  18  OIL_RATE_3_days_ago   23260 non-null  float64
#  19  OIL_RATE_2_days_ago   23260 non-null  float64
#  20  OIL_RATE_1_days_ago   23260 non-null  float64
# dtypes: float64(21)
# memory usage: 3.9 MB

# %%
best_params
model = XGBRFRegressor(n_estimators=best_params[0], 
                       max_depth=best_params[1], 
                       max_leaves=best_params[2], 
                       learning_rate=best_params[3])
model.fit(X_train, y_train)
importances = model.feature_importances_


fig, axes = plt.subplots(figsize=(8,5))
sns.barplot(x=X_train.columns, y=importances);
axes.set_ylabel('Важность признака')
axes.set_xlabel('Признаки')
x_ticklabels = axes.get_xticklabels()
for label in x_ticklabels:
    label.set_rotation(45)
    label.set_fontsize(8)

# %%
data = X_test.iloc[[0]]

total_point = X_test.shape[0]
count_days_ago = data.shape[1] - 1

answer = []

for i in range(total_point):
    
    value_point = float(model.predict(data))
    
    
    answer.append(value_point)
        
    data.iloc[0 , - count_days_ago : - 1] = data.iloc[0 , - count_days_ago + 1 : ]
    data.iloc[0 , - 1] = value_point

answer = pd.Series(answer, index=y_test.index)

# %%
graph_with_prediction(y_train=y_train, y_test=y_test, answer_model=answer, model_name='Xgboost')
