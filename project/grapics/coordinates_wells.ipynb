# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.graph_objects as go
from plotly.offline import iplot
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams.update({'font.size': 11})

import warnings 
warnings.simplefilter('ignore')
import pickle


# %config InlineBackend.figure_formats = 'svg'

plt.rcParams['font.family'] = 'Times New Roman'

mpl.rcParams.update({'font.size': 11})

# %%
cord_well = pd.read_csv('../../data/basic_data/coords.csv')
cord_well.dropna(axis=1, how='all', inplace=True)
with open('../name_wells_pickle/dict_name_well.pickle', 'rb') as f:
    dict_well_name = pickle.load(f)
cord_well['WELL_NAME'] = cord_well['WELL_NAME'].map(dict_well_name)
cord_well.dropna(inplace=True)
cord_well = cord_well.set_index('WELL_NAME')
cord_well.sort_index(inplace=True);
cord_well
# Out:
#             COORD_X   COORD_Y        X2        Y2
# WELL_NAME
# 0.0         8723.72   9233.28   8734.83   9266.15
# 1.0         3230.05  10023.99   3228.69  10026.23
# 2.0         9139.72   8098.28   9107.33   8136.30
# 3.0        13248.72   3294.28  13180.20   3253.84
# 4.0        11009.72   8856.28  11029.73   8939.46
# ...             ...       ...       ...       ...
# 261.0       8969.61   6577.69   9031.06   6206.56
# 262.0       5366.43   3089.94   5452.10   2358.23
# 263.0       8085.09   5164.86   7826.63   5871.54
# 264.0       8485.91   1848.55   8630.94   1258.34
# 265.0       7611.36   1573.21   7700.59    973.57
#
# [266 rows x 4 columns]

# %%
cord_well.columns = ["Координата входа в пласт X, м", 'Координата входа в пласт Y, м', 'X', 'Y']
X = cord_well["Координата входа в пласт X, м"]
Y = cord_well['Координата входа в пласт Y, м']
fig, axes = plt.subplots()
sns.scatterplot(x=X, y=Y);
for x, y, well in zip(X, Y, cord_well.index):
    plt.annotate(well, xy=(x, y), xytext=(-5, 3), textcoords='offset points', ha='left', va='bottom', fontsize=4)
offset = 500
plt.figure(figsize=(15, 12))
axes.set_xlim(X.min() - offset, X.max() + offset);
axes.set_ylim(Y.min() - offset, Y.max() + offset);

# %%
X = cord_well[cord_well['COORD_Y'] < 14000]['COORD_X']
Y = cord_well[cord_well['COORD_Y'] < 14000]['COORD_Y']
fig, axes = plt.subplots()
sns.scatterplot(x=X, y=Y)
#for x, y, well in zip(X, Y, cord_well['WELL_NAME']):
#    plt.annotate(well, xy=(x, y), xytext=(-5, 3), textcoords='offset points', ha='left', va='bottom', fontsize=8)
#offset = 500
plt.figure(figsize=(12, 10))

# %%
data = cord_well.dropna()
X = data['COORD_X']
Y = data['COORD_Y']
fig, axes = plt.subplots()
sns.scatterplot(x=X, y=Y)
#for x, y, well in zip(X, Y, cord_well['WELL_NAME']):
#    plt.annotate(well, xy=(x, y), xytext=(-5, 3), textcoords='offset points', ha='left', va='bottom', fontsize=8)
#offset = 500
plt.figure(figsize=(12, 10))

# %%
graph_wells = pd.DataFrame(index=range(266))
for well in range(266):
    graph_wells[f'Скважина {well}'] = round(np.sqrt(np.square(cord_well['COORD_X'] - cord_well[cord_well.index == well]['COORD_X'].values) +
                        np.square(cord_well['COORD_Y'] - cord_well[cord_well.index == well]['COORD_Y'].values)), 1)
